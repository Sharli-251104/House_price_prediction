# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("Housing.csv")
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
columns_to_encode = ['mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'prefarea', 'furnishingstatus']

# %%
label_encoders = {}
for column in columns_to_encode:
    label_encoders[column] = LabelEncoder()
    data[column] = label_encoders[column].fit_transform(data[column])

# %%
x = data.drop(columns=['price'])

# %%
x
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          0         0
# 1    8960         4          4        4         1          0         0
# 2    9960         3          2        2         1          0         1
# 3    7500         4          2        2         1          0         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          0         1
# 541  2400         3          1        1         0          0         0
# 542  3620         2          1        1         1          0         0
# 543  2910         3          1        1         0          0         0
# 544  3850         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# ...

# %%
x.columns = ['feature_' + str(i) for i in range(len(x.columns))]

# %%
x
# Out:
#      feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0         7420          4          2          3          1          0
# 1         8960          4          4          4          1          0
# 2         9960          3          2          2          1          0
# 3         7500          4          2          2          1          0
# 4         7420          4          1          2          1          1
# ..         ...        ...        ...        ...        ...        ...
# 540       3000          2          1          1          1          0
# 541       2400          3          1          1          0          0
# 542       3620          2          1          1          1          0
# 543       2910          3          1          1          0          0
# 544       3850          3          1          2          1          0
#
#      feature_6  feature_7  feature_8  feature_9  feature_10  feature_11
# ...

# %%
y = data['price']

# %%
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
x_train
# Out:
#      feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 46        6000          3          2          4          1          0
# 93        7200          3          2          1          1          0
# 335       3816          2          1          1          1          0
# 412       2610          3          1          2          1          0
# 471       3750          3          1          2          1          0
# ..         ...        ...        ...        ...        ...        ...
# 71        6000          4          2          4          1          0
# 106       5450          4          2          1          1          0
# 270       4500          3          2          3          1          0
# 435       4040          2          1          1          1          0
# 102       5500          3          2          4          1          1
#
#      feature_6  feature_7  feature_8  feature_9  feature_10  feature_11
# ...

# %%
x_test
# Out:
#      feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 316       5900          4          2          2          0          0
# 77        6500          3          2          3          1          0
# 360       4040          2          1          1          1          0
# 90        5000          3          1          2          1          0
# 493       3960          3          1          1          1          0
# ..         ...        ...        ...        ...        ...        ...
# 15        6000          4          1          2          1          0
# 357       6930          4          1          2          0          0
# 39        6000          4          2          4          1          0
# 54        6000          3          2          2          1          1
# 155       6100          3          2          1          1          0
#
#      feature_6  feature_7  feature_8  feature_9  feature_10  feature_11
# ...

# %%
y_train
# Out:
# 46     7525000
# 93     6300000
# 335    3920000
# 412    3430000
# 471    3010000
#         ...
# 71     6755000
# 106    6160000
# 270    4340000
# 435    3290000
# 102    6195000
# Name: price, Length: 436, dtype: int64

# %%
y_test
# Out:
# 316    4060000
# 77     6650000
# 360    3710000
# 90     6440000
# 493    2800000
#         ...
# 15     9100000
# 357    3773000
# 39     7910000
# 54     7350000
# 155    5530000
# Name: price, Length: 109, dtype: int64

# %%
data_regressor = DecisionTreeRegressor(random_state= 42)

# %%
data_regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
y_pred = data_regressor.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 2688177649082.569

# %%
new_features = x_test.iloc[0].values.reshape(1,-1)

# %%
x_test.iloc[0]
# Out:
# feature_0     5900
# feature_1        4
# feature_2        2
# feature_3        2
# feature_4        0
# feature_5        0
# feature_6        1
# feature_7        0
# feature_8        0
# feature_9        1
# feature_10       0
# feature_11       2
# Name: 316, dtype: int64

# %%
predicted_price = data_regressor.predict(new_features)
# Out:
# C:\Users\mail2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
print("Predicted price for new house:", predicted_price[0])
# Out:
# Predicted price for new house: 5250000.0

# %%
new_features = x_test.iloc[1].values.reshape(1,-1)

# %%
x_test.iloc[1]
# Out:
# feature_0     6500
# feature_1        3
# feature_2        2
# feature_3        3
# feature_4        1
# feature_5        0
# feature_6        0
# feature_7        0
# feature_8        1
# feature_9        0
# feature_10       1
# feature_11       0
# Name: 77, dtype: int64

# %%
predicted_price = data_regressor.predict(new_features)
print("Predicted price for new house:", predicted_price[0])
# Out:
# Predicted price for new house: 7840000.0
# C:\Users\mail2\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
